# %% [markdown]
# # Q3. Apply Insertion sort and Merge sort algorithm.

# %% [markdown]
# a. Create arrays/list of following sizes 10, 100,100, 10000, 100000,1000000,10000000, 1000000000, 1000000000000. Add random values in these arrays or list. Save these lists in different files.

# %% [markdown]
# b. Load these values into lists from file and pass it to insertion sort and merge sort algorithm. Save the result in file.

# %% [markdown]
# c. Note time at start of algorithm.

# %% [markdown]
# d. Note time at end of algorithm.

# %% [markdown]
# e. Calculate the time difference and fill the table shared in the end.

# %%
import random;
import time;

# %%
def InsertionSort(Array):
    for j in range(1,len(Array)):
       key = Array[j]
       i = j-1
       while i>=0 and Array[i]>key:
           Array[i+1] = Array[i]
           i = i-1
       Array[i+1] = key
    return Array;

# %%
# merge two sorted arrays to return a sorted array
def merge(L, R):
    i = 0 # current index in the L array
    j = 0 # current index in the R array
    ret = []
    while i < len(L) and j < len(R):
        if L[i] < R[j]:
            ret.append(L[i])
            i += 1
        else:   # ties go to R.  Doesn't really matter.
            ret.append(R[j])
            j += 1
    while i < len(L):
        ret.append(L[i])
        i += 1
    while j < len(R):
        ret.append(R[j])
        j+= 1
    return ret
        
def mergeSort(A):
    n = len(A)
    if n <= 1:
        return A
    L = mergeSort(A[:round(n/2)])
    R = mergeSort(A[round(n/2):n])
    return merge(L,R)

# %% [markdown]
# # Array of size 10

# %%
## Array of size 10
arr10 = [random.randint(0,100) for i in range(10)]
StrArr10 = str(arr10)
print(arr10)
with open("arr10.txt",'w',encoding = 'utf-8') as arr10:
  arr10.write(StrArr10)
# Out:
# [85, 77, 76, 65, 20, 89, 99, 3, 81, 25]

# %% [markdown]
# # Array of size 100

# %%
## Array of size 100
arr100 = [random.randint(0,1000) for i in range(100)]
StrArr100 = str(arr100)
print(arr100)
with open("arr100.txt",'w',encoding = 'utf-8') as arr100:
  arr100.write(StrArr100)
# Out:
# [234, 302, 465, 859, 936, 563, 948, 57, 774, 797, 103, 307, 78, 993, 146, 821, 220, 150, 137, 411, 365, 441, 550, 830, 792, 516, 29, 770, 963, 196, 488, 658, 812, 345, 821, 775, 215, 668, 90, 45, 708, 512, 754, 241, 342, 511, 273, 324, 344, 567, 590, 850, 431, 276, 656, 217, 761, 126, 733, 905, 659, 593, 843, 695, 409, 885, 895, 853, 790, 631, 568, 977, 409, 610, 640, 931, 610, 447, 714, 762, 146, 297, 335, 125, 895, 573, 584, 650, 953, 41, 805, 527, 171, 310, 726, 548, 783, 99, 292, 391]

# %% [markdown]
# # Array of size 1000

# %%
## Array of size 1000
arr1000 = [random.randint(0,10000) for i in range(1000)]
StrArr1000 = str(arr1000)
print(arr1000)
with open("arr1000.txt",'w',encoding = 'utf-8') as arr1000:
  arr1000.write(StrArr1000)
# Out:
672, 778105, 148374, 785696, 871746, 267129, 220794, 884263, 717969, 245851, 51797, 310555, 450846, 578816, 995186, 786540, 904440, 629157, 823407, 600896, 606814, 534214, 786621, 677479, 667599, 603880, 184198, 945665, 830364, 373250, 52059, 147024, 11939, 174601, 18584, 847371, 483847, 657714, 523041, 126710, 213347, 399670, 555867, 135051, 454230, 544337, 43758, 237783, 773296, 539143, 115538, 121944, 33182, 942975, 452826, 141211, 254389, 173804, 588639, 496279, 318430, 946570, 180364, 525539, 709302, 501967, 527160, 116811, 647255, 591147, 173600, 13236, 791509, 266071, 46298, 7974, 604408, 292769, 721271, 62591, 36060, 515073, 433569, 510792, 726101, 862270, 438580, 168645, 359072, 120864, 633824, 934687, 484507, 438870, 427593, 4126, 310744, 175193, 547183, 363317, 348002, 941123, 854010, 98172, 681613, 918635, 79504, 254628, 353322, 459316, 481374, 743094, 380403, 530821, 181726, 451829, 612686, 37213, 354464, 745261, 160012, 647928, 253482, 681888, 374035, 567929, 588484, 342695, 276685, 686574, 804991, 867747, 874256, 422216, 379842, 172018, 965943, 70345, 156674, 79494, 465215, 843016, 894953, 109071, 952880, 972086, 478900, 29891, 395602, 534250, 73475, 954896, 84378, 88922, 570561, 336860, 216596, 277007, 991452, 989792, 102250, 76388, 694816, 992900, 706251, 349996, 913893, 396133, 741253, 461103, 652819, 416939, 638036, 517372, 571023, 762922, 720278, 792242, 74787, 315241, 376826, 115579, 897891, 810504, 52401, 896543, 904482, 478317, 17197, 778317, 646979, 608589, 229288, 624836, 193761, 62098, 310606, 257760, 884535, 93439, 796921, 220009, 706215, 270084, 21278, 524145, 488615, 961566, 466448, 471625, 737677, 906865, 72709, 245663, 972667, 85323, 728582, 929682, 415416, 666920, 50085, 902212, 754299, 432093, 47322, 769968, 22905, 536997, 711389, 687689, 545772, 994158, 57957, 315872, 463793, 210117, 6156, 956161, 573921, 550497, 310489, 667611, 240719, 179178, 98399, 271079, 561243, 554950, 130475, 781298, 328164, 132400, 372792, 554857, 73667, 408659, 990073, 47063, 650429, 774381, 908220, 74603, 100273, 762951, 881127, 959563, 269338, 901583, 652696, 37279, 334838, 286811, 99959, 913203, 558808, 780560, 371635, 746270, 544451, 772142, 987191, 7450, 840506, 726473, 67 ...

# %% [markdown]
# # Array of size 1000000

# %%
## Array of size 1000000
#arr1000000 = [random.randint(0,100000) for i in range(1000000)]
#StrArr1000000= str(arr1000000)
#print(arr1000000)
#with open("arr1000000.txt",'w',encoding = 'utf-8') as arr1000000:
#  arr1000000.write(StrArr1000000)

# %% [markdown]
# # Array of size 1000000000

# %%
## Array of size 1000000000
#arr1000000000 = [random.randint(0,10000000) for i in range(1000000000)]
#StrArr1000000000 = str(arr1000000000)
#print(arr1000000000)
#with open("arr1000000000.txt",'w',encoding = 'utf-8') as arr1000000000:
 # arr1000000000.write(StrArr1000000000)

# %% [markdown]
# # Array of size 1000000000000

# %%
## Array of size 1000000000000
#arr1000000000000 = [random.randint(0,10000000000000) for i in range(1000000000000)]
#StrArr1000000000000 = str(arr1000000000000)
#print(arr1000000000000)
#with open("arr1000000000.txt",'w',encoding = 'utf-8') as arr1000000000000:
#  arr1000000000000.write(StrArr1000000000000)

# %% [markdown]
# # Time Difference for Array of size 10

# %%
with open("arr10.txt",'r',encoding = 'utf-8') as Arr10:
 i=Arr10.read()

#Change srting list to integer list
j = i[1:len(i)-1]
A = list(map(int,j.split(",")))
print("Array: ", A)

#################### Insertion sort ######################
t0 = time.time()
I = InsertionSort(A)
t1 = time.time()-t0
print("Insertion Sort: " , I)
print("Time for Insertion Sort: " , t1)
#################### Merge sort ##########################
t2 = time.time()
m = mergeSort(A)
t3 = time.time()-t2
print("Merge Sort: " , m)
print("Time for Merge Sort: " , t3)
# Out:
# Array:  [85, 77, 76, 65, 20, 89, 99, 3, 81, 25]
# Insertion Sort:  [3, 20, 25, 65, 76, 77, 81, 85, 89, 99]
# Time for Insertion Sort:  0.0009999275207519531
# Merge Sort:  [3, 20, 25, 65, 76, 77, 81, 85, 89, 99]
# Time for Merge Sort:  0.0

# %% [markdown]
# # Time Difference for Array of size 100

# %%
with open("arr100.txt",'r',encoding = 'utf-8') as Arr100 :
 i=Arr100.read()

#Change srting list to integer list
j = i[1:len(i)-1]
A = list(map(int,j.split(",")))
#print("Array: ", A)

#################### Insertion sort ######################
t0 = time.time()
I = InsertionSort(A)
t1 = time.time()-t0
#print("Insertion Sort: " , I)
print("Time for Insertion Sort: " , t1)
#################### Merge sort ##########################
t2 = time.time()
m = mergeSort(A)
t3 = time.time()-t2
#print("Merge Sort: " , m)
print("Time for Merge Sort: " , t3)
# Out:
# Time for Insertion Sort:  0.003997325897216797
# Time for Merge Sort:  0.002997875213623047

# %% [markdown]
# # Time Difference for Array of size 1000

# %%
with open("arr1000.txt",'r',encoding = 'utf-8')as Arr1000:
 i=Arr1000.read()

#Change srting list to integer list
j = i[1:len(i)-1]
A = list(map(int,j.split(",")))
#print("Array: ", A)

#################### Insertion sort ######################
t0 = time.time()
I = InsertionSort(A)
t1 = time.time()-t0
#print("Insertion Sort: " , I)
print("Time for Insertion Sort: " , t1)
#################### Merge sort ##########################
t2 = time.time()
m = mergeSort(A)
t3 = time.time()-t2
#print("Merge Sort: " , m)
print("Time for Merge Sort: " , t3)
# Out:
# Time for Insertion Sort:  0.14509081840515137
# Time for Merge Sort:  0.0

# %% [markdown]
# # Time Difference for Array of size 10000

# %%
with open("arr10000.txt",'r',encoding = 'utf-8') as Arr10000:
 i=Arr10000.read()

#Change srting list to integer list
j = i[1:len(i)-1]
A = list(map(int,j.split(",")))
#print("Array: ", A)

#################### Insertion sort ######################
t0 = time.time()
I = InsertionSort(A)
t1 = time.time()-t0
#print("Insertion Sort: " , I)
print("Time for Insertion Sort: " , t1)
#################### Merge sort ##########################
t2 = time.time()
m = mergeSort(A)
t3 = time.time()-t2
#print("Merge Sort: " , m)
print("Time for Merge Sort: " , t3)
# Out:
# Time for Insertion Sort:  22.515409231185913
# Time for Merge Sort:  0.4070882797241211

# %% [markdown]
# # Time Difference for Array of size 100000

# %%
with open("arr100000.txt",'r',encoding = 'utf-8') as Arr100000:
 i=Arr100000.read()

#Change srting list to integer list
j = i[1:len(i)-1]
A = list(map(int,j.split(",")))
#print("Array: ", A)

#################### Insertion sort ######################
t0 = time.time()
I = InsertionSort(A)
t1 = time.time()-t0
#print("Insertion Sort: " , I)
print("Time for Insertion Sort: " , t1)
#################### Merge sort ##########################
t2 = time.time()
m = mergeSort(A)
t3 = time.time()-t2
#print("Merge Sort: " , m)
print("Time for Merge Sort: " , t3)
# Out:
# Time for Insertion Sort:  2311.1045644283295
# Time for Merge Sort:  2.7308437824249268

# %% [markdown]
# # Time Difference for Array of size 1000000

# %%
#with open("arr1000000.txt",'r',encoding = 'utf-8') as Arr1000000:
# i=Arr1000000.read()

###Change srting list to integer list
#j = i[1:len(i)-1]
#A = list(map(int,j.split(",")))
#print("Array: ", A)

#################### Insertion sort ######################
#t0 = time.time()
#I = InsertionSort(A)
#t1 = time.time()-t0
#print("Insertion Sort: " , I)
#print("Time for Insertion Sort: " , t1)
#################### Merge sort ##########################
#t2 = time.time()
#m = mergeSort(A)
#t3 = time.time()-t2
#print("Merge Sort: " , m)
#print("Time for Merge Sort: " , t3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-cf0760c0d0b0> in <module>
#       9 #################### Insertion sort ######################
#      10 t0 = time.time()
# ---> 11 I = InsertionSort(A)
#      12 t1 = time.time()-t0
#      13 #print("Insertion Sort: " , I)
#
# <ipython-input-7-df41c05fdabc> in InsertionSort(Array)
#       4        i = j-1
#       5        while i>=0 and Array[i]>key:
# ----> 6            Array[i+1] = Array[i]
#       7            i = i-1
#       8        Array[i+1] = key
#
# KeyboardInterrupt:

# %% [markdown]
# # Time Difference for Array of size 1000000000

# %%
#with open("arr10000.txt",'r',encoding = 'utf-8') as Arr1000000000:
# i=Arr1000000000.read()

###Change srting list to integer list
#j = i[1:len(i)-1]
#A = list(map(int,j.split(",")))
#print("Array: ", A)

#################### Insertion sort ######################
#t0 = time.time()
#I = InsertionSort(A)
#t1 = time.time()-t0
#print("Insertion Sort: " , I)
#print("Time for Insertion Sort: " , t1)
#################### Merge sort ##########################
#t2 = time.time()
#m = mergeSort(A)
#t3 = time.time()-t2
#print("Merge Sort: " , m)
#print("Time for Merge Sort: " , t3)

# %% [markdown]
# # Time Difference for Array of size 1000000000000

# %%
#with open("arr1000000000000.txt",'r',encoding = 'utf-8') as Arr1000000000000:
# i=Arr1000000000000.read()

##Change srting list to integer list
#j = i[1:len(i)-1]
#A = list(map(int,j.split(",")))
#print("Array: ", A)

#################### Insertion sort ######################
#t0 = time.time()
#I = InsertionSort(A)
#t1 = time.time()-t0
#print("Insertion Sort: " , I)
#print("Time for Insertion Sort: " , t1)
#################### Merge sort ##########################
#t2 = time.time()
#m = mergeSort(A)
#t3 = time.time()-t2
#print("Merge Sort: " , m)
#print("Time for Merge Sort: " , t3)
